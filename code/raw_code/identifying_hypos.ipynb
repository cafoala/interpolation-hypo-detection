# %%
import pandas as pd
import numpy as np
import copy
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error, cohen_kappa_score
import matplotlib.pyplot as plt
import seaborn as sns
from functools import reduce
import scipy.stats as stats
import warnings
import sys
sys.path.append("/Users/cr591/OneDrive - University of Exeter/Desktop/pyCGM/pyCGM")
import metrics as cgm

warnings.filterwarnings('ignore')

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('~/OneDrive - University of Exeter/Desktop/PhD/Projects/interpolation-for-hypo-detection/dexcom-maths-exploration/data/tidy_data/interp_dataset.csv')
df.dropna(subset=['glc'], inplace=True)

# %%
cols = ['cut_glc', 'pchip', 'linear','cubicspline', 'akima', 'polynomial_3', 
        'polynomial_5', 'polynomial_7', 'matern', 'rq', 'rbf']

# %%
df[cols] = df[cols].round(2)
df_results = cgm.hypoglycemic_episodes(df, 'time', 'glc', 'ID', 
                                       interpolate=False, breakdown=True)

# %%
def overlapping_frame(row, dataframe):
    print(row.ID)
    return dataframe.loc[(dataframe['ID']==row['ID']) & 
                    (((dataframe['start_time']<=row['start_time']) & 
                        (dataframe['end_time']>=row['start_time']))| 
                    ((dataframe['start_time']<=row['end_time']) & 
                        (dataframe['end_time']>=row['end_time'])) |
                    ((row['start_time']<=dataframe['start_time']) & 
                        (row['end_time']>=dataframe['start_time']))| 
                    ((row['start_time']<=dataframe['end_time']) & 
                        (row['end_time']>=dataframe['end_time'])))]

# %%
def calculate_sens(original_df, comparison_df, col, aligned=False):
    false_positive = 0
    true_positive = 0
    false_negative = 0
    for i, row in original_df.iterrows():
        sub_df = overlapping_frame(row, comparison_df)

        if sub_df.shape[0]==0:
            false_negative += 1
            falsey = [col, row.ID, row['start_time'], row['start_time'], 
                      row['end_time'], row['end_time']- row['start_time'],
                      row['lv2'], np.nan, np.nan, np.nan, np.nan, -1]
            if aligned:
                aligned_results.append({'col': col, 'ID': row.ID, 
                      'global_start':row['start_time'], 
                      '5_min start':row['start_time'], 
                      '5_min_end':row['end_time'], 
                      '5_min_diff':row['end_time']- row['start_time'],
                      '5_min_lv2': row['lv2'],
                      'false_value':-1})
            
        elif sub_df.shape[0] == 1:
            true_positive += 1
            comparison_df = comparison_df.drop(index=sub_df.index[0])
            if aligned:
                aligned_results.append({'col':col, 'ID':row.ID, 
                           'global_start':row['start_time'], 
                           '5_min start':row['start_time'], 
                           '5_min_end':row['end_time'], 
                          '5_min_diff':row['end_time']- row['start_time'], 
                          '5_min_lv2':row['lv2'], 
                          '15_min start':sub_df.iloc[0]['start_time'], 
                          '15_min_end':sub_df.iloc[0]['end_time'], 
                          '15_min_diff':sub_df.iloc[0]['end_time'] - sub_df.iloc[0]['start_time'], 
                          '15_min_lv2':sub_df.iloc[0]['lv2'], 'false_value':0})

        elif sub_df.shape[0] > 1:
            true_positive += 1
            comparison_df = comparison_df.drop(index=sub_df.index[0])
            if aligned: 
                aligned_results.append({'col':col, 'ID':row.ID, 
                           'global_start':row['start_time'], 
                           '5_min start':row['start_time'], 
                           '5_min_end':row['end_time'], 
                          '5_min_diff':row['end_time']- row['start_time'], 
                          '5_min_lv2':row['lv2'], 
                          '15_min start':sub_df.iloc[0]['start_time'], 
                          '15_min_end':sub_df.iloc[0]['end_time'], 
                          '15_min_diff':sub_df.iloc[0]['end_time'] - sub_df.iloc[0]['start_time'], 
                          '15_min_lv2':sub_df.iloc[0]['lv2'], 'false_value':0})

    for i, row in comparison_df.iterrows():
        false_positive += 1
        if aligned:
            aligned_results.append({'col':col, 'ID':row.ID, 
                           'global_start':row['start_time'], 
                          '15_min start':row['start_time'], 
                          '15_min_end':row['end_time'], 
                          '15_min_diff':row['end_time'] - sub_df.iloc[0]['start_time'], 
                          '15_min_lv2':row['lv2'], 'false_value':+1})
    
    return [true_positive, false_negative, false_positive]

# %%
aligned_results = []
results_list = []
for col in cols:
    sub_df = df[['time', 'ID', col]]
    sub_df.columns = ['time', 'ID', 'glc']
 
    if col == 'cut_glc': interval_size = 15 
    else: interval_size = 5
    
    cut_results = cgm.hypoglycemic_episodes(sub_df, 'time', 'glc', 'ID',
                                                interpolate=False,
                                                breakdown=True,
                                                interval_size=interval_size)
    # all
    results_list.append([col, 'all'] + calculate_sens(df_results, cut_results, 
                                                      col, aligned=True))
    #lv1
    lv1_results = cut_results[cut_results['lv2']==False].reset_index(drop=True)
    df_lv1 = df_results[df_results['lv2']==False].reset_index(drop=True)
    results_list.append([col, 'lv1'] + calculate_sens(df_lv1, lv1_results, col))
    
    # lv2
    lv2_results = cut_results[cut_results['lv2']==True].reset_index(drop=True)
    df_lv2 = df_results[df_results['lv2']==True].reset_index(drop=True)
    results_list.append([col, 'lv2'] + calculate_sens(df_lv2, lv2_results, col))

results_frame = pd.DataFrame(results_list, columns=['method', 'lv', 'TP', 'FN', 
                                                    'FP'])
aligned_results = pd.DataFrame(aligned_results)

# %%
results_frame['recall'] = results_frame['TP']/(results_frame['TP']+results_frame['FN'])
results_frame['prec'] = results_frame['TP']/(results_frame['TP']+results_frame['FP'])
results_frame['csi'] = results_frame['TP']/(results_frame['TP']+results_frame['FP']+results_frame['FN'])
results_frame = results_frame.sort_values(['lv', 'recall', 'csi'], ascending=True)

# %%
results_frame.round(3).to_csv('confusion_matrix_hypos.csv', index=False)

# %%
for methods in aligned_results.col.values:
    method_df = aligned_results[aligned_results['col']==methods].sort_values(['ID', 'global_start'])
    name = './Aligned_results/aligned_results_' + methods + '.csv'
    method_df.to_csv(name)

# %%
aligned_results.sort_values(['col', 'ID', 'global_start']).head(10)
# Out:
#         col             ID        global_start         5_min start  \
# 1738  akima  1001_baseline 2018-01-08 19:21:00 2018-01-08 19:21:00
# 1739  akima  1001_baseline 2018-01-10 00:41:00 2018-01-10 00:41:00
# 1740  akima  1001_baseline 2018-01-10 13:01:00 2018-01-10 13:01:00
# 1741  akima  1001_baseline 2018-01-11 03:06:00 2018-01-11 03:06:00
# 1742  akima  1001_baseline 2018-01-11 04:16:00 2018-01-11 04:16:00
# 1743  akima  1001_baseline 2018-01-11 06:06:00 2018-01-11 06:06:00
# 1744  akima  1001_baseline 2018-01-11 11:41:00 2018-01-11 11:41:00
# 1745  akima   1003_6months 2018-09-21 16:07:00 2018-09-21 16:07:00
# 1746  akima   1003_6months 2018-09-22 00:07:00 2018-09-22 00:07:00
# 1747  akima   1003_6months 2018-09-22 03:07:00 2018-09-22 03:07:00
#
#                5_min_end      5_min_diff 5_min_lv2        15_min start  \
# 1738 2018-01-08 19:46:00 0 days 00:25:00      True 2018-01-08 19:21:00
# 1739 2018-01-10 01:31:00 0 days 00:50:00      True 2018-01-10 00:41:00
# 1740 2018-01-10 13:16:00 0 days 00:15:00     False 2018-01-10 13:01:00
# 1741 2018-01-11 03:26:00 0 days 00:20:00     False 2018-01-11 03:11:00
# 1742 2018-01-11 04:56:00 0 days 00:40:00      True 2018-01-11 03:51:00
# 1743 2018-01-11 06:21:00 0 days 00:15:00     False                 NaT
# 1744 2018-01-11 12:11:00 0 days 00:30:00     False 2018-01-11 11:41:00
# 1745 2018-09-21 18:52:00 0 days 02:45:00      True 2018-09-21 16:02:00
# 1746 2018-09-22 00:27:00 0 days 00:20:00     False 2018-09-22 00:07:00
# 1747 2018-09-22 04:17:00 0 days 01:10:00     False 2018-09-22 03:07:00
#
#               15_min_end     15_min_diff 15_min_lv2  false_value
# 1738 2018-01-08 19:41:00 0 days 00:20:00      False            0
# 1739 2018-01-10 01:31:00 0 days 00:50:00       True            0
# 1740 2018-01-10 13:21:00 0 days 00:20:00      False            0
# 1741 2018-01-11 03:26:00 0 days 00:15:00      False            0
# 1742 2018-01-11 04:56:00 0 days 01:05:00       True            0
# 1743                 NaT             NaT        NaN           -1
# 1744 2018-01-11 12:11:00 0 days 00:30:00      False            0
# 1745 2018-09-21 18:52:00 0 days 02:50:00       True            0
# 1746 2018-09-22 00:27:00 0 days 00:20:00      False            0
# 1747 2018-09-22 04:17:00 0 days 01:10:00      False            0

# %%
aligned_results.sort_values(['col', 'ID', 'global_start']).to_csv('aligned_results_rounded.csv', index=False)

# %% [markdown]
# ## Distribution of incorrect results

# %%
def incorrect_substypes(df_method):
    lv1_lv2 = df_method.loc[(df_method['5_min_lv2']==False) & (df_method['15_min_lv2']==True)].shape[0] # FP lv2 - was actually a lv1
    lv2_lv1 = df_method.loc[(df_method['5_min_lv2']==True) & (df_method['15_min_lv2']==False)].shape[0] # FN lv2 - was identified as lv1
    lv1_none = df_method.loc[(df_method['5_min_lv2']==False) & (pd.isnull(df_method['15_min_lv2']))].shape[0] # FN lv1 - was not identified as hypo
    none_lv1 = df_method.loc[(pd.isnull(df_method['5_min_lv2'])) & (df_method['15_min_lv2']==False)].shape[0] # FP lv1 - was identified as lv1
    lv2_none = df_method.loc[(df_method['5_min_lv2']==True) & (pd.isnull(df_method['15_min_lv2']))].shape[0] # FN lv2 - identified as none
    none_lv2 = df_method.loc[(pd.isnull(df_method['5_min_lv2'])) & (df_method['15_min_lv2']==True)].shape[0] # FP lv2 - was none but identified as lv2
    return pd.DataFrame([[lv1_lv2, lv2_lv1,  lv1_none, none_lv1,lv2_none, none_lv2]])

# %%
results = aligned_results.groupby('col').apply(incorrect_substypes).unstack() #.reset_index().drop(columns='level_1')
results.columns=['lv1_lv2', 'lv2_lv1', 'lv1_none','none_lv1', 
                                     'lv2_none', 'none_lv2']

# %%
results # actual_predicted
# Out:
#               lv1_lv2  lv2_lv1  lv1_none  none_lv1  lv2_none  none_lv2
# col
# akima               8        8        12        11         0         0
# cubicspline        12        7         9        13         0         0
# cut_glc             0       19        28         1         3         0
# linear              3       14        17         4         0         0
# matern             11        6         8        14         1         0
# pchip               9       10        11         8         0         0
# polynomial_3       12        7         9        13         0         0
# polynomial_5       12        6         8        13         0         0
# polynomial_7       12        6        10        14         0         0
# rbf                10        6        10        15         0         0
# rq                  7       12        15         9         0         0

# %% [markdown]
# ## Calculate person wise stats

# %%
df['ID_code'] = df.ID.apply(lambda x: x[:4])

# %%
aligned_results['ID_code'] = aligned_results.ID.apply(lambda x: x[:4])

# %%
def number_false_values(sub_id):
    FN_all = sub_id.loc[sub_id.false_value==-1].shape[0]
    TP_all = sub_id.loc[sub_id.false_value==0].shape[0]
    FP_all = sub_id.loc[sub_id.false_value==1].shape[0]
    
    TPlv1 = sub_id[((sub_id['5_min_lv2']==False) & (sub_id['15_min_lv2']==False))].shape[0]
    FNlv1 = sub_id[(sub_id['5_min_lv2']==False) & (sub_id['15_min_lv2']!=False)].shape[0]
    FPlv1 = sub_id[(sub_id['5_min_lv2']!=False) & (sub_id['15_min_lv2']==False)].shape[0]

    TPlv2 = sub_id[((sub_id['5_min_lv2']==True) & (sub_id['15_min_lv2']==True))].shape[0]
    FNlv2 = sub_id[(sub_id['5_min_lv2']==True) & (sub_id['15_min_lv2']!=True)].shape[0]
    FPlv2 = sub_id[(sub_id['5_min_lv2']!=True) & (sub_id['15_min_lv2']==True)].shape[0]
    
    return pd.DataFrame([[TP_all, FP_all, FN_all, TPlv1, FPlv1, FNlv1, TPlv2, FPlv2, FNlv2]],
                       columns = ['TP_all', 'FP_all', 'FN_all', 'TPlv1', 'FPlv1', 'FNlv1', 'TPlv2', 'FPlv2', 'FNlv2'])

# %%
results_personal = aligned_results.groupby(['ID_code', 'col'], dropna=False).apply(number_false_values).reset_index().drop(columns='level_2')

# %%
melted = results_personal.melt(id_vars=['ID_code', 'col'])

# %%
melted
# Out:
#      ID_code           col variable  value
# 0       1001         akima   TP_all      6
# 1       1001   cubicspline   TP_all      7
# 2       1001       cut_glc   TP_all      5
# 3       1001        linear   TP_all      6
# 4       1001        matern   TP_all      7
# 5       1001         pchip   TP_all      6
# 6       1001  polynomial_3   TP_all      7
# 7       1001  polynomial_5   TP_all      7
# 8       1001  polynomial_7   TP_all      7
# 9       1001           rbf   TP_all      7
# 10      1001            rq   TP_all      7
# 11      1003         akima   TP_all     19
# 12      1003   cubicspline   TP_all     19
# 13      1003       cut_glc   TP_all     19
# 14      1003        linear   TP_all     19
# 15      1003        matern   TP_all     19
# 16      1003         pchip   TP_all     19
# 17      1003  polynomial_3   TP_all     19
# 18      1003  polynomial_5   TP_all     19
# 19      1003  polynomial_7   TP_all     19
# 20      1003           rbf   TP_all     19
# 21      1003            rq   TP_all     19
# 22      1004         akima   TP_all      9
# 23      1004   cubicspline   TP_all      9
# 24      1004       cut_glc   TP_all      8
# 25      1004        linear   TP_all      9
# 26      1004        matern   TP_all      9
# 27      1004         pchip   TP_all      9
# 28      1004  polynomial_3   TP_all      9
# 29      1004  polynomial_5   TP_all      9
# 30      1004  polynomial_7   TP_all      9
# 31      1004           rbf   TP_all      9
# 32      1004            rq   TP_all      9
# 33      1005         akima   TP_all      2
# 34      1005   cubicspline   TP_all      2
# 35      1005       cut_glc   TP_all      2
# 36      1005        linear   TP_all      2
# 37      1005        matern   TP_all      2
# 38      1005         pchip   TP_all      2
# 39      1005  polynomial_3   TP_all      2
# 40      1005  polynomial_5   TP_all      2
# 41      1005  polynomial_7   TP_all      2
# 42      1005           rbf   TP_all      2
# 43      1005            rq   TP_all      2
# 44      1006         akima   TP_all      5
# 45      1006   cubicspline   TP_all      5
# 46      1006       cut_glc   TP_all      5
# 47      1006        linear   TP_all      5
# 48      1006        matern   TP_all      5
# 49      1006         pchip   TP_all      5
# 50      1006  polynomial_3   TP_all      5
# 51      1006  polynomial_5   TP_all      5
# 52      1006  polynomial_7   TP_all      5
# 53      1006           rbf   TP_all      5
# 54      1006            rq   TP_all      5
# 55      1007         akima   TP_all      2
# 56      1007   cubicspline   TP_all      2
# 57      1007       cut_glc   TP_all      2
# 58      1007        linear   TP_all      2
# 59      1007        matern   TP_all      2
# 60      1007         pchip   TP_all      2
# 61      1007  polynomial_3   TP_all      2
# 62      1007  polynomial_5   TP_all      2
# 63      1007  polynomial_7   TP_all      2
# 64      1007           rbf   TP_all      2
# 65      1007            rq   TP_all      2
# 66      1008         akima   TP_all     21
# 67      1008   cubicspline   TP_all     21
# 68      1008       cut_glc   TP_all     20
# 69      1008        linear   TP_all     21
# 70      1008        matern   TP_all     21
# 71      1008         pchip   TP_all     21
# 72      1008  polynomial_3   TP_all     21
# 73      1008  polynomial_5   TP_all     21
# 74      1008  polynomial_7   TP_all     21
# 75      1008           rbf   TP_all     21
# 76      1008            rq   TP_all     21
# 77      1010         akima   TP_all     33
# 78      1010   cubicspline   TP_all     33
# 79      1010       cut_glc   TP_all     32
# 80      1010        linear   TP_all     33
# 81      1010        matern   TP_all     33
# 82      1010         pchip   TP_all     33
# 83      1010  polynomial_3   TP_all     33
# 84      1010  polynomial_5   TP_all     33
# 85      1010  polynomial_7   TP_all     33
# 86      1010           rbf   TP_all     33
# 87      1010            rq   TP_all     33
# 88      1011         akima   TP_all      0
# 89      1011   cubicspline   TP_all      0
# 90      1011       cut_glc   TP_all      0
# 91      1011        linear   TP_all      0
# 92      1011        matern   TP_all      0
# 93      1011         pchip   TP_all      0
# 94      1011  polynomial_3   TP_all      0
# 95      1011  polynomial_5   TP_all      0
# 96      1011  polynomial_7   TP_all      0
# 97      1011           rbf   TP_all      0
# 98      1011            rq   TP_all      0
# 99      1013         akima   TP_all     12
# 100     1013   cubicspline   TP_all     12
# 101     1013       cut_glc   TP_all     11
# 102     1013        linear   TP_all     12
# 103     1013        matern   TP_all     12
# 104     1013         pchip   TP_all     12
# 105     1013  polynomial_3   TP_all     12
# 106     1013  polynomial_5   TP_all     12
# 107     1013  polynomial_7   TP_all     12
# 108     1013           rbf   TP_all     12
# 109     1013            rq   TP_all     12
# 110     1014         akima   TP_all     16
# 111     1014   cubicspline   TP_all     16
# 112     1014       cut_glc   TP_all     16
# 113     1014        linear   TP_all     16
# 114     1014        matern   TP_all     16
# 115     1014         pchip   TP_all     16
# 116     1014  polynomial_3   TP_all     16
# 117     1014  polynomial_5   TP_all     16
# 118     1014  polynomial_7   TP_all     16
# 119     1014           rbf   TP_all     16
# 120     1014            rq   TP_all     16
# 121     1015         akima   TP_all      1
# 122     1015   cubicspline   TP_all      1
# 123     1015       cut_glc   TP_all      1
# 124     1015        linear   TP_all      1
# 125     1015        matern   TP_all      1
# 126     1015         pchip   TP_all      1
# 127     1015  polynomial_3   TP_all      1
# 128     1015  polynomial_5   TP_all      1
# 129     1015  polynomial_7   TP_all      1
# 130     1015           rbf   TP_all      1
# 131     1015            rq   TP_all      1
# 132     1021         akima   TP_all      3
# 133     1021   cubicspline   TP_all      3
# 134     1021       cut_glc   TP_all      3
# 135     1021        linear   TP_all      3
# 136     1021        matern   TP_all      3
# 137     1021         pchip   TP_all      3
# 138     1021  polynomial_3   TP_all      3
# 139     1021  polynomial_5   TP_all      3
# 140     1021  polynomial_7   TP_all      3
# 141     1021           rbf   TP_all      3
# 142     1021            rq   TP_all      3
# 143     1022         akima   TP_all      5
# 144     1022   cubicspline   TP_all      5
# 145     1022       cut_glc   TP_all      5
# 146     1022        linear   TP_all      5
# 147     1022        matern   TP_all      5
# 148     1022         pchip   TP_all      5
# 149     1022  polynomial_3   TP_all      5
# 150     1022  polynomial_5   TP_all      5
# 151     1022  polynomial_7   TP_all      5
# 152     1022           rbf   TP_all      5
# 153     1022            rq   TP_all      5
# 154     1025         akima   TP_all      1
# 155     1025   cubicspline   TP_all      1
# 156     1025       cut_glc   TP_all      1
# 157     1025        linear   TP_all      1
# 158     1025        matern   TP_all      1
# 159     1025         pchip   TP_all      1
# 160     1025  polynomial_3   TP_all      1
# 161     1025  polynomial_5   TP_all      1
# 162     1025  polynomial_7   TP_all      1
# 163     1025           rbf   TP_all      1
# 164     1025            rq   TP_all      1
# 165     1026         akima   TP_all      1
# 166     1026   cubicspline   TP_all      1
# 167     1026       cut_glc   TP_all      1
# 168     1026        linear   TP_all      1
# 169     1026        matern   TP_all      1
# 170     1026         pchip   TP_all      1
# 171     1026  polynomial_3   TP_all      1
# 172     1026  polynomial_5   TP_all      1
# 173     1026  polynomial_7   TP_all      1
# 174     1026           rbf   TP_all      1
# 175     1026            rq   TP_all      1
# 176     1027         akima   TP_all      3
# 177     1027   cubicspline   TP_all      3
# 178     1027       cut_glc   TP_all      3
# 179     1027        linear   TP_all      3
# 180     1027        matern   TP_all      3
# 181     1027         pchip   TP_all      3
# 182     1027  polynomial_3   TP_all      3
# 183     1027  polynomial_5   TP_all      3
# 184     1027  polynomial_7   TP_all      3
# 185     1027           rbf   TP_all      3
# 186     1027            rq   TP_all      3
# 187     1029         akima   TP_all      4
# 188     1029   cubicspline   TP_all      4
# 189     1029       cut_glc   TP_all      4
# 190     1029        linear   TP_all      4
# 191     1029        matern   TP_all      4
# 192     1029         pchip   TP_all      4
# 193     1029  polynomial_3   TP_all      4
# 194     1029  polynomial_5   TP_all      4
# 195     1029  polynomial_7   TP_all      4
# 196     1029           rbf   TP_all      4
# 197     1029            rq   TP_all      4
# 198     1030         akima   TP_all      2
# 199     1030   cubicspline   TP_all      2
# 200     1030       cut_glc   TP_all      1
# 201     1030        linear   TP_all      2
# 202     1030        matern   TP_all      2
# 203     1030         pchip   TP_all      2
# 204     1030  polynomial_3   TP_all      2
# 205     1030  polynomial_5   TP_all      2
# 206     1030  polynomial_7   TP_all      2
# 207     1030           rbf   TP_all      2
# 208     1030            rq   TP_all      2
# 209     1031         akima   TP_all      1
# 210     1031   cubicspline   TP_all      1
# 211     1031       cut_glc   TP_all      1
# 212     1031        linear   TP_all      1
# 213     1031        matern   TP_all      1
# 214     1031         pchip   TP_all      1
# 215     1031  polynomial_3   TP_all      1
# 216     1031  polynomial_5   TP_all      1
# 217     1031  polynomial_7   TP_all      1
# 218     1031           rbf   TP_all      1
# 219     1031            rq   TP_all      1
# 220     1032         akima   TP_all      6
# 221     1032   cubicspline   TP_all      6
# 222     1032       cut_glc   TP_all      4
# 223     1032        linear   TP_all      4
# 224     1032        matern   TP_all      6
# 225     1032         pchip   TP_all      5
# 226     1032  polynomial_3   TP_all      6
# 227     1032  polynomial_5   TP_all      6
# 228     1032  polynomial_7   TP_all      6
# 229     1032           rbf   TP_all      6
# 230     1032            rq   TP_all      4
# 231     1034         akima   TP_all     13
# 232     1034   cubicspline   TP_all     13
# 233     1034       cut_glc   TP_all     13
# 234     1034        linear   TP_all     13
# 235     1034        matern   TP_all     13
# 236     1034         pchip   TP_all     13
# 237     1034  polynomial_3   TP_all     13
# 238     1034  polynomial_5   TP_all     13
# 239     1034  polynomial_7   TP_all     13
# 240     1034           rbf   TP_all     13
# 241     1034            rq   TP_all     13
# 242     1035         akima   TP_all      8
# 243     1035   cubicspline   TP_all      8
# 244     1035       cut_glc   TP_all      8
# 245     1035        linear   TP_all      8
# 246     1035        matern   TP_all      8
# 247     1035         pchip   TP_all      8
# 248     1035  polynomial_3   TP_all      8
# 249     1035  polynomial_5   TP_all      8
# 250     1035  polynomial_7   TP_all      8
# 251     1035           rbf   TP_all      8
# 252     1035            rq   TP_all      8
# 253     1040         akima   TP_all     15
# 254     1040   cubicspline   TP_all     15
# 255     1040       cut_glc   TP_all     14
# 256     1040        linear   TP_all     15
# 257     1040        matern   TP_all     15
# 258     1040         pchip   TP_all     15
# 259     1040  polynomial_3   TP_all     15
# 260     1040  polynomial_5   TP_all     15
# 261     1040  polynomial_7   TP_all     15
# 262     1040           rbf   TP_all     15
# 263     1040            rq   TP_all     15
# 264     1045         akima   TP_all      5
# 265     1045   cubicspline   TP_all      5
# 266     1045       cut_glc   TP_all      4
# 267     1045        linear   TP_all      5
# 268     1045        matern   TP_all      5
# 269     1045         pchip   TP_all      5
# 270     1045  polynomial_3   TP_all      5
# 271     1045  polynomial_5   TP_all      5
# 272     1045  polynomial_7   TP_all      5
# 273     1045           rbf   TP_all      5
# 274     1045            rq   TP_all      5
# 275     1046         akima   TP_all      7
# 276     1046   cubicspline   TP_all      7
# 277     1046       cut_glc   TP_all      6
# 278     1046        linear   TP_all      7
# 279     1046        matern   TP_all      6
# 280     1046         pchip   TP_all      7
# 281     1046  polynomial_3   TP_all      7
# 282     1046  polynomial_5   TP_all      7
# 283     1046  polynomial_7   TP_all      7
# 284     1046           rbf   TP_all      7
# 285     1046            rq   TP_all      7
# 286     1047         akima   TP_all      2
# 287     1047   cubicspline   TP_all      2
# 288     1047       cut_glc   TP_all      2
# 289     1047        linear   TP_all      2
# 290     1047        matern   TP_all      2
# 291     1047         pchip   TP_all      2
# 292     1047  polynomial_3   TP_all      2
# 293     1047  polynomial_5   TP_all      2
# 294     1047  polynomial_7   TP_all      2
# 295     1047           rbf   TP_all      2
# 296     1047            rq   TP_all      2
# 297     1048         akima   TP_all      6
# 298     1048   cubicspline   TP_all      6
# 299     1048       cut_glc   TP_all      6
# 300     1048        linear   TP_all      6
# 301     1048        matern   TP_all      6
# 302     1048         pchip   TP_all      6
# 303     1048  polynomial_3   TP_all      6
# 304     1048  polynomial_5   TP_all      6
# 305     1048  polynomial_7   TP_all      6
# 306     1048           rbf   TP_all      6
# 307     1048            rq   TP_all      6
# 308     1049         akima   TP_all     10
# 309     1049   cubicspline   TP_all     10
# 310     1049       cut_glc   TP_all     10
# 311     1049        linear   TP_all     10
# 312     1049        matern   TP_all     10
# 313     1049         pchip   TP_all     10
# 314     1049  polynomial_3   TP_all     10
# 315     1049  polynomial_5   TP_all     10
# 316     1049  polynomial_7   TP_all     10
# 317     1049           rbf   TP_all     10
# 318     1049            rq   TP_all     10
# 319     1051         akima   TP_all     12
# 320     1051   cubicspline   TP_all     12
# 321     1051       cut_glc   TP_all     12
# 322     1051        linear   TP_all     12
# 323     1051        matern   TP_all     12
# 324     1051         pchip   TP_all     12
# 325     1051  polynomial_3   TP_all     12
# 326     1051  polynomial_5   TP_all     12
# 327     1051  polynomial_7   TP_all     12
# 328     1051           rbf   TP_all     12
# 329     1051            rq   TP_all     12
# 330     2001         akima   TP_all      8
# 331     2001   cubicspline   TP_all      8
# 332     2001       cut_glc   TP_all      8
# 333     2001        linear   TP_all      8
# 334     2001        matern   TP_all      8
# 335     2001         pchip   TP_all      8
# 336     2001  polynomial_3   TP_all      8
# 337     2001  polynomial_5   TP_all      8
# 338     2001  polynomial_7   TP_all      8
# 339     2001           rbf   TP_all      8
# 340     2001            rq   TP_all      8
# 341     2003         akima   TP_all      2
# 342     2003   cubicspline   TP_all      2
# 343     2003       cut_glc   TP_all      1
# 344     2003        linear   TP_all      2
# 345     2003        matern   TP_all      2
# 346     2003         pchip   TP_all      2
# 347     2003  polynomial_3   TP_all      2
# 348     2003  polynomial_5   TP_all      2
# 349     2003  polynomial_7   TP_all      2
# 350     2003           rbf   TP_all      2
# 351     2003            rq   TP_all      2
# 352     2004         akima   TP_all     16
# 353     2004   cubicspline   TP_all     16
# 354     2004       cut_glc   TP_all     16
# 355     2004        linear   TP_all     16
# 356     2004        matern   TP_all     16
# 357     2004         pchip   TP_all     16
# 358     2004  polynomial_3   TP_all     16
# 359     2004  polynomial_5   TP_all     16
# 360     2004  polynomial_7   TP_all     16
# 361     2004           rbf   TP_all     16
# 362     2004            rq   TP_all     16
# 363     2008         akima   TP_all      6
# 364     2008   cubicspline   TP_all      6
# 365     2008       cut_glc   TP_all      6
# 366     2008        linear   TP_all      6
# 367     2008        matern   TP_all      6
# 368     2008         pchip   TP_all      6
# 369     2008  polynomial_3   TP_all      6
# 370     2008  polynomial_5   TP_all      6
# 371     2008  polynomial_7   TP_all      6
# 372     2008           rbf   TP_all      6
# 373     2008            rq   TP_all      6
# 374     2009         akima   TP_all      6
# 375     2009   cubicspline   TP_all      6
# 376     2009       cut_glc   TP_all      6
# 377     2009        linear   TP_all      6
# 378     2009        matern   TP_all      6
# 379     2009         pchip   TP_all      6
# 380     2009  polynomial_3   TP_all      6
# 381     2009  polynomial_5   TP_all      6
# 382     2009  polynomial_7   TP_all      6
# 383     2009           rbf   TP_all      6
# 384     2009            rq   TP_all      6
# 385     2012         akima   TP_all      3
# 386     2012   cubicspline   TP_all      4
# 387     2012       cut_glc   TP_all      3
# 388     2012        linear   TP_all      3
# 389     2012        matern   TP_all      4
# 390     2012         pchip   TP_all      3
# 391     2012  polynomial_3   TP_all      4
# 392     2012  polynomial_5   TP_all      4
# 393     2012  polynomial_7   TP_all      4
# 394     2012           rbf   TP_all      4
# 395     2012            rq   TP_all      3
# 396     2013         akima   TP_all      4
# 397     2013   cubicspline   TP_all      5
# 398     2013       cut_glc   TP_all      3
# 399     2013        linear   TP_all      3
# 400     2013        matern   TP_all      5
# 401     2013         pchip   TP_all      5
# 402     2013  polynomial_3   TP_all      5
# 403     2013  polynomial_5   TP_all      5
# 404     2013  polynomial_7   TP_all      5
# 405     2013           rbf   TP_all      5
# 406     2013            rq   TP_all      5
# 407     2016         akima   TP_all      3
# 408     2016   cubicspline   TP_all      3
# 409     2016       cut_glc   TP_all      3
# 410     2016        linear   TP_all      3
# 411     2016        matern   TP_all      3
# 412     2016         pchip   TP_all      3
# 413     2016  polynomial_3   TP_all      3
# 414     2016  polynomial_5   TP_all      3
# 415     2016  polynomial_7   TP_all      3
# 416     2016           rbf   TP_all      3
# 417     2016            rq   TP_all      3
# 418     2017         akima   TP_all      3
# 419     2017   cubicspline   TP_all      3
# 420     2017       cut_glc   TP_all      3
# 421     2017        linear   TP_all      3
# 422     2017        matern   TP_all      4
# 423     2017         pchip   TP_all      4
# 424     2017  polynomial_3   TP_all      3
# 425     2017  polynomial_5   TP_all      4
# 426     2017  polynomial_7   TP_all      3
# 427     2017           rbf   TP_all      3
# 428     2017            rq   TP_all      3
# 429     2020         akima   TP_all     12
# 430     2020   cubicspline   TP_all     12
# 431     2020       cut_glc   TP_all     12
# 432     2020        linear   TP_all     12
# 433     2020        matern   TP_all     12
# 434     2020         pchip   TP_all     12
# 435     2020  polynomial_3   TP_all     12
# 436     2020  polynomial_5   TP_all     12
# 437     2020  polynomial_7   TP_all     12
# 438     2020           rbf   TP_all     12
# 439     2020            rq   TP_all     12
# 440     2023         akima   TP_all      3
# 441     2023   cubicspline   TP_all      3
# 442     2023       cut_glc   TP_all      2
# 443     2023        linear   TP_all      2
# 444     2023        matern   TP_all      3
# 445     2023         pchip   TP_all      3
# 446     2023  polynomial_3   TP_all      3
# 447     2023  polynomial_5   TP_all      3
# 448     2023  polynomial_7   TP_all      3
# 449     2023           rbf   TP_all      3
# 450     2023            rq   TP_all      2
# 451     2024         akima   TP_all      9
# 452     2024   cubicspline   TP_all      9
# 453     2024       cut_glc   TP_all      9
# 454     2024        linear   TP_all      9
# 455     2024        matern   TP_all      9
# 456     2024         pchip   TP_all      9
# 457     2024  polynomial_3   TP_all      9
# 458     2024  polynomial_5   TP_all      9
# 459     2024  polynomial_7   TP_all      9
# 460     2024           rbf   TP_all      9
# 461     2024            rq   TP_all      9
# 462     2026         akima   TP_all      4
# 463     2026   cubicspline   TP_all      4
# 464     2026       cut_glc   TP_all      3
# 465     2026        linear   TP_all      4
# 466     2026        matern   TP_all      4
# 467     2026         pchip   TP_all      4
# 468     2026  polynomial_3   TP_all      4
# 469     2026  polynomial_5   TP_all      4
# 470     2026  polynomial_7   TP_all      4
# 471     2026           rbf   TP_all      4
# 472     2026            rq   TP_all      4
# 473     2027         akima   TP_all      6
# 474     2027   cubicspline   TP_all      6
# 475     2027       cut_glc   TP_all      6
# 476     2027        linear   TP_all      6
# 477     2027        matern   TP_all      6
# 478     2027         pchip   TP_all      6
# 479     2027  polynomial_3   TP_all      6
# 480     2027  polynomial_5   TP_all      6
# 481     2027  polynomial_7   TP_all      6
# 482     2027           rbf   TP_all      6
# 483     2027            rq   TP_all      6
# 484     2028         akima   TP_all      4
# 485     2028   cubicspline   TP_all      4
# 486     2028       cut_glc   TP_all      3
# 487     2028        linear   TP_all      4
# 488     2028        matern   TP_all      4
# 489     2028         pchip   TP_all      4
# 490     2028  polynomial_3   TP_all      4
# 491     2028  polynomial_5   TP_all      4
# 492     2028  polynomial_7   TP_all      4
# 493     2028           rbf   TP_all      4
# 494     2028            rq   TP_all      4
# 495     2029         akima   TP_all      9
# 496     2029   cubicspline   TP_all      9
# 497     2029       cut_glc   TP_all      9
# 498     2029        linear   TP_all      9
# 499     2029        matern   TP_all      9
# 500     2029         pchip   TP_all      9
# 501     2029  polynomial_3   TP_all      9
# 502     2029  polynomial_5   TP_all      9
# 503     2029  polynomial_7   TP_all      9
# 504     2029           rbf   TP_all      9
# 505     2029            rq   TP_all      9
# 506     2030         akima   TP_all      4
# 507     2030   cubicspline   TP_all      4
# 508     2030       cut_glc   TP_all      3
# 509     2030        linear   TP_all      4
# 510     2030        matern   TP_all      4
# 511     2030         pchip   TP_all      4
# 512     2030  polynomial_3   TP_all      4
# 513     2030  polynomial_5   TP_all      4
# 514     2030  polynomial_7   TP_all      4
# 515     2030           rbf   TP_all      4
# 516     2030            rq   TP_all      4
# 517     2031         akima   TP_all      7
# 518     2031   cubicspline   TP_all      7
# 519     2031       cut_glc   TP_all      7
# 520     2031        linear   TP_all      7
# 521     2031        matern   TP_all      7
# 522     2031         pchip   TP_all      7
# 523     2031  polynomial_3   TP_all      7
# 524     2031  polynomial_5   TP_all      7
# 525     2031  polynomial_7   TP_all      7
# 526     2031           rbf   TP_all      7
# 527     2031            rq   TP_all      7
# 528     2032         akima   TP_all      7
# 529     2032   cubicspline   TP_all      7
# 530     2032       cut_glc   TP_all      7
# 531     2032        linear   TP_all      7
# 532     2032        matern   TP_all      7
# 533     2032         pchip   TP_all      7
# 534     2032  polynomial_3   TP_all      7
# 535     2032  polynomial_5   TP_all      7
# 536     2032  polynomial_7   TP_all      7
# 537     2032           rbf   TP_all      7
# 538     2032            rq   TP_all      6
# 539     2035         akima   TP_all      4
# 540     2035   cubicspline   TP_all      4
# 541     2035       cut_glc   TP_all      4
# 542     2035        linear   TP_all      4
# 543     2035        matern   TP_all      4
# 544     2035         pchip   TP_all      4
# 545     2035  polynomial_3   TP_all      4
# 546     2035  polynomial_5   TP_all      4
# 547     2035  polynomial_7   TP_all      4
# 548     2035           rbf   TP_all      4
# 549     2035            rq   TP_all      4
# 550     2036         akima   TP_all      8
# 551     2036   cubicspline   TP_all      8
# 552     2036       cut_glc   TP_all      7
# 553     2036        linear   TP_all      7
# 554     2036        matern   TP_all      8
# 555     2036         pchip   TP_all      8
# 556     2036  polynomial_3   TP_all      8
# 557     2036  polynomial_5   TP_all      8
# 558     2036  polynomial_7   TP_all      8
# 559     2036           rbf   TP_all      8
# 560     2036            rq   TP_all      8
# 561     2038         akima   TP_all     11
# 562     2038   cubicspline   TP_all     11
# 563     2038       cut_glc   TP_all     11
# 564     2038        linear   TP_all     11
# 565     2038        matern   TP_all     11
# 566     2038         pchip   TP_all     11
# 567     2038  polynomial_3   TP_all     11
# 568     2038  polynomial_5   TP_all     11
# 569     2038  polynomial_7   TP_all     11
# 570     2038           rbf   TP_all     11
# 571     2038            rq   TP_all     11
# 572     2039         akima   TP_all      5
# 573     2039   cubicspline   TP_all      5
# 574     2039       cut_glc   TP_all      4
# 575     2039        linear   TP_all      5
# 576     2039        matern   TP_all      5
# 577     2039         pchip   TP_all      5
# 578     2039  polynomial_3   TP_all      5
# 579     2039  polynomial_5   TP_all      5
# 580     2039  polynomial_7   TP_all      4
# 581     2039           rbf   TP_all      4
# 582     2039            rq   TP_all      4
# 583     2040         akima   TP_all      8
# 584     2040   cubicspline   TP_all      8
# 585     2040       cut_glc   TP_all      8
# 586     2040        linear   TP_all      8
# 587     2040        matern   TP_all      8
# 588     2040         pchip   TP_all      8
# 589     2040  polynomial_3   TP_all      8
# 590     2040  polynomial_5   TP_all      8
# 591     2040  polynomial_7   TP_all      8
# 592     2040           rbf   TP_all      8
# 593     2040            rq   TP_all      8
# 594     2041         akima   TP_all      7
# 595     2041   cubicspline   TP_all      7
# 596     2041       cut_glc   TP_all      7
# 597     2041        linear   TP_all      7
# 598     2041        matern   TP_all      7
# 599     2041         pchip   TP_all      7
# 600     2041  polynomial_3   TP_all      7
# 601     2041  polynomial_5   TP_all      7
# 602     2041  polynomial_7   TP_all      7
# 603     2041           rbf   TP_all      7
# 604     2041            rq   TP_all      7
# 605     2042         akima   TP_all      4
# 606     2042   cubicspline   TP_all      4
# 607     2042       cut_glc   TP_all      4
# 608     2042        linear   TP_all      4
# 609     2042        matern   TP_all      4
# 610     2042         pchip   TP_all      4
# 611     2042  polynomial_3   TP_all      4
# 612     2042  polynomial_5   TP_all      4
# 613     2042  polynomial_7   TP_all      4
# 614     2042           rbf   TP_all      4
# 615     2042            rq   TP_all      4
# 616     2043         akima   TP_all     15
# 617     2043   cubicspline   TP_all     15
# 618     2043       cut_glc   TP_all     15
# 619     2043        linear   TP_all     15
# 620     2043        matern   TP_all     15
# 621     2043         pchip   TP_all     15
# 622     2043  polynomial_3   TP_all     15
# 623     2043  polynomial_5   TP_all     15
# 624     2043  polynomial_7   TP_all     15
# 625     2043           rbf   TP_all     15
# 626     2043            rq   TP_all     15
# 627     2045         akima   TP_all      8
# 628     2045   cubicspline   TP_all      8
# 629     2045       cut_glc   TP_all      8
# 630     2045        linear   TP_all      8
# 631     2045        matern   TP_all      8
# 632     2045         pchip   TP_all      8
# 633     2045  polynomial_3   TP_all      8
# 634     2045  polynomial_5   TP_all      8
# 635     2045  polynomial_7   TP_all      8
# 636     2045           rbf   TP_all      8
# 637     2045            rq   TP_all      8
# 638     1001         akima   FP_all      0
# 639     1001   cubicspline   FP_all      0
# 640     1001       cut_glc   FP_all      0
# 641     1001        linear   FP_all      0
# 642     1001        matern   FP_all      0
# 643     1001         pchip   FP_all      0
# 644     1001  polynomial_3   FP_all      0
# 645     1001  polynomial_5   FP_all      0
# 646     1001  polynomial_7   FP_all      0
# 647     1001           rbf   FP_all      0
# 648     1001            rq   FP_all      0
# 649     1003         akima   FP_all      0
# 650     1003   cubicspline   FP_all      0
# 651     1003       cut_glc   FP_all      0
# 652     1003        linear   FP_all      0
# 653     1003        matern   FP_all      0
# 654     1003         pchip   FP_all      0
# 655     1003  polynomial_3   FP_all      0
# 656     1003  polynomial_5   FP_all      0
# 657     1003  polynomial_7   FP_all      0
# 658     1003           rbf   FP_all      0
# 659     1003            rq   FP_all      0
# 660     1004         akima   FP_all      0
# 661     1004   cubicspline   FP_all      0
# 662     1004       cut_glc   FP_all      0
# 663     1004        linear   FP_all      0
# 664     1004        matern   FP_all      0
# 665     1004         pchip   FP_all      0
# 666     1004  polynomial_3   FP_all      0
# 667     1004  polynomial_5   FP_all      0
# 668     1004  polynomial_7   FP_all      0
# 669     1004           rbf   FP_all      0
# 670     1004            rq   FP_all      0
# 671     1005         akima   FP_all      0
# 672     1005   cubicspline   FP_all      0
# 673     1005       cut_glc   FP_all      0
# 674     1005        linear   FP_all      0
# 675     1005        matern   FP_all      0
# 676     1005         pchip   FP_all      0
# 677     1005  polynomial_3   FP_all      0
# 678     1005  polynomial_5   FP_all      0
# 679     1005  polynomial_7   FP_all      0
# 680     1005           rbf   FP_all      0
# 681     1005            rq   FP_all      0
# 682     1006         akima   FP_all      0
# 683     1006   cubicspline   FP_all      0
# 684     1006       cut_glc   FP_all      0
# 685     1006        linear   FP_all      0
# 686     1006        matern   FP_all      0
# 687     1006         pchip   FP_all      0
# 688     1006  polynomial_3   FP_all      0
# 689     1006  polynomial_5   FP_all      0
# 690     1006  polynomial_7   FP_all      0
# 691     1006           rbf   FP_all      0
# 692     1006            rq   FP_all      0
# 693     1007         akima   FP_all      0
# 694     1007   cubicspline   FP_all      0
# 695     1007       cut_glc   FP_all      0
# 696     1007        linear   FP_all      0
# 697     1007        matern   FP_all      0
# 698     1007         pchip   FP_all      0
# 699     1007  polynomial_3   FP_all      0
# 700     1007  polynomial_5   FP_all      0
# 701     1007  polynomial_7   FP_all      0
# 702     1007           rbf   FP_all      0
# 703     1007            rq   FP_all      0
# 704     1008         akima   FP_all      0
# 705     1008   cubicspline   FP_all      0
# 706     1008       cut_glc   FP_all      0
# 707     1008        linear   FP_all      0
# 708     1008        matern   FP_all      0
# 709     1008         pchip   FP_all      0
# 710     1008  polynomial_3   FP_all      0
# 711     1008  polynomial_5   FP_all      0
# 712     1008  polynomial_7   FP_all      0
# 713     1008           rbf   FP_all      0
# 714     1008            rq   FP_all      0
# 715     1010         akima   FP_all      0
# 716     1010   cubicspline   FP_all      0
# 717     1010       cut_glc   FP_all      0
# 718     1010        linear   FP_all      0
# 719     1010        matern   FP_all      0
# 720     1010         pchip   FP_all      0
# 721     1010  polynomial_3   FP_all      0
# 722     1010  polynomial_5   FP_all      0
# 723     1010  polynomial_7   FP_all      0
# 724     1010           rbf   FP_all      0
# 725     1010            rq   FP_all      0
# 726     1011         akima   FP_all      0
# 727     1011   cubicspline   FP_all      0
# 728     1011       cut_glc   FP_all      0
# 729     1011        linear   FP_all      0
# 730     1011        matern   FP_all      0
# 731     1011         pchip   FP_all      0
# 732     1011  polynomial_3   FP_all      0
# 733     1011  polynomial_5   FP_all      0
# 734     1011  polynomial_7   FP_all      0
# 735     1011           rbf   FP_all      0
# 736     1011            rq   FP_all      0
# 737     1013         akima   FP_all      2
# 738     1013   cubicspline   FP_all      2
# 739     1013       cut_glc   FP_all      0
# 740     1013        linear   FP_all      0
# 741     1013        matern   FP_all      3
# 742     1013         pchip   FP_all      1
# 743     1013  polynomial_3   FP_all      2
# 744     1013  polynomial_5   FP_all      2
# 745     1013  polynomial_7   FP_all      2
# 746     1013           rbf   FP_all      3
# 747     1013            rq   FP_all      1
# 748     1014         akima   FP_all      0
# 749     1014   cubicspline   FP_all      0
# 750     1014       cut_glc   FP_all      0
# 751     1014        linear   FP_all      0
# 752     1014        matern   FP_all      0
# 753     1014         pchip   FP_all      0
# 754     1014  polynomial_3   FP_all      0
# 755     1014  polynomial_5   FP_all      0
# 756     1014  polynomial_7   FP_all      0
# 757     1014           rbf   FP_all      0
# 758     1014            rq   FP_all      0
# 759     1015         akima   FP_all      0
# 760     1015   cubicspline   FP_all      0
# 761     1015       cut_glc   FP_all      0
# 762     1015        linear   FP_all      0
# 763     1015        matern   FP_all      0
# 764     1015         pchip   FP_all      0
# 765     1015  polynomial_3   FP_all      0
# 766     1015  polynomial_5   FP_all      0
# 767     1015  polynomial_7   FP_all      0
# 768     1015           rbf   FP_all      0
# 769     1015            rq   FP_all      0
# 770     1021         akima   FP_all      0
# 771     1021   cubicspline   FP_all      0
# 772     1021       cut_glc   FP_all      0
# 773     1021        linear   FP_all      0
# 774     1021        matern   FP_all      0
# 775     1021         pchip   FP_all      0
# 776     1021  polynomial_3   FP_all      0
# 777     1021  polynomial_5   FP_all      0
# 778     1021  polynomial_7   FP_all      0
# 779     1021           rbf   FP_all      0
# 780     1021            rq   FP_all      0
# 781     1022         akima   FP_all      0
# 782     1022   cubicspline   FP_all      0
# 783     1022       cut_glc   FP_all      0
# 784     1022        linear   FP_all      0
# 785     1022        matern   FP_all      0
# 786     1022         pchip   FP_all      0
# 787     1022  polynomial_3   FP_all      0
# 788     1022  polynomial_5   FP_all      0
# 789     1022  polynomial_7   FP_all      0
# 790     1022           rbf   FP_all      0
# 791     1022            rq   FP_all      0
# 792     1025         akima   FP_all      0
# 793     1025   cubicspline   FP_all      0
# 794     1025       cut_glc   FP_all      0
# 795     1025        linear   FP_all      0
# 796     1025        matern   FP_all      0
# 797     1025         pchip   FP_all      0
# 798     1025  polynomial_3   FP_all      0
# 799     1025  polynomial_5   FP_all      0
# 800     1025  polynomial_7   FP_all      0
# 801     1025           rbf   FP_all      0
# 802     1025            rq   FP_all      0
# 803     1026         akima   FP_all      0
# 804     1026   cubicspline   FP_all      0
# 805     1026       cut_glc   FP_all      0
# 806     1026        linear   FP_all      0
# 807     1026        matern   FP_all      0
# 808     1026         pchip   FP_all      0
# 809     1026  polynomial_3   FP_all      0
# 810     1026  polynomial_5   FP_all      0
# 811     1026  polynomial_7   FP_all      0
# 812     1026           rbf   FP_all      0
# 813     1026            rq   FP_all      0
# 814     1027         akima   FP_all      0
# 815     1027   cubicspline   FP_all      0
# 816     1027       cut_glc   FP_all      0
# 817     1027        linear   FP_all      0
# 818     1027        matern   FP_all      0
# 819     1027         pchip   FP_all      0
# 820     1027  polynomial_3   FP_all      0
# 821     1027  polynomial_5   FP_all      0
# 822     1027  polynomial_7   FP_all      0
# 823     1027           rbf   FP_all      0
# 824     1027            rq   FP_all      0
# 825     1029         akima   FP_all      0
# 826     1029   cubicspline   FP_all      0
# 827     1029       cut_glc   FP_all      0
# 828     1029        linear   FP_all      0
# 829     1029        matern   FP_all      0
# 830     1029         pchip   FP_all      0
# 831     1029  polynomial_3   FP_all      0
# 832     1029  polynomial_5   FP_all      0
# 833     1029  polynomial_7   FP_all      0
# 834     1029           rbf   FP_all      0
# 835     1029            rq   FP_all      0
# 836     1030         akima   FP_all      0
# 837     1030   cubicspline   FP_all      0
# 838     1030       cut_glc   FP_all      0
# 839     1030        linear   FP_all      0
# 840     1030        matern   FP_all      0
# 841     1030         pchip   FP_all      0
# 842     1030  polynomial_3   FP_all      0
# 843     1030  polynomial_5   FP_all      0
# 844     1030  polynomial_7   FP_all      0
# 845     1030           rbf   FP_all      0
# 846     1030            rq   FP_all      0
# 847     1031         akima   FP_all      0
# 848     1031   cubicspline   FP_all      1
# 849     1031       cut_glc   FP_all      0
# 850     1031        linear   FP_all      0
# 851     1031        matern   FP_all      1
# 852     1031         pchip   FP_all      0
# 853     1031  polynomial_3   FP_all      1
# 854     1031  polynomial_5   FP_all      1
# 855     1031  polynomial_7   FP_all      2
# 856     1031           rbf   FP_all      2
# 857     1031            rq   FP_all      0
# 858     1032         akima   FP_all      1
# 859     1032   cubicspline   FP_all      1
# 860     1032       cut_glc   FP_all      0
# 861     1032        linear   FP_all      0
# 862     1032        matern   FP_all      1
# 863     1032         pchip   FP_all      1
# 864     1032  polynomial_3   FP_all      1
# 865     1032  polynomial_5   FP_all      1
# 866     1032  polynomial_7   FP_all      1
# 867     1032           rbf   FP_all      1
# 868     1032            rq   FP_all      1
# 869     1034         akima   FP_all      1
# 870     1034   cubicspline   FP_all      1
# 871     1034       cut_glc   FP_all      0
# 872     1034        linear   FP_all      0
# 873     1034        matern   FP_all      1
# 874     1034         pchip   FP_all      0
# 875     1034  polynomial_3   FP_all      1
# 876     1034  polynomial_5   FP_all      1
# 877     1034  polynomial_7   FP_all      1
# 878     1034           rbf   FP_all      1
# 879     1034            rq   FP_all      0
# 880     1035         akima   FP_all      0
# 881     1035   cubicspline   FP_all      0
# 882     1035       cut_glc   FP_all      0
# 883     1035        linear   FP_all      0
# 884     1035        matern   FP_all      0
# 885     1035         pchip   FP_all      0
# 886     1035  polynomial_3   FP_all      0
# 887     1035  polynomial_5   FP_all      0
# 888     1035  polynomial_7   FP_all      0
# 889     1035           rbf   FP_all      0
# 890     1035            rq   FP_all      0
# 891     1040         akima   FP_all      0
# 892     1040   cubicspline   FP_all      0
# 893     1040       cut_glc   FP_all      0
# 894     1040        linear   FP_all      0
# 895     1040        matern   FP_all      0
# 896     1040         pchip   FP_all      0
# 897     1040  polynomial_3   FP_all      0
# 898     1040  polynomial_5   FP_all      0
# 899     1040  polynomial_7   FP_all      0
# 900     1040           rbf   FP_all      0
# 901     1040            rq   FP_all      0
# 902     1045         akima   FP_all      0
# 903     1045   cubicspline   FP_all      0
# 904     1045       cut_glc   FP_all      0
# 905     1045        linear   FP_all      0
# 906     1045        matern   FP_all      0
# 907     1045         pchip   FP_all      0
# 908     1045  polynomial_3   FP_all      0
# 909     1045  polynomial_5   FP_all      0
# 910     1045  polynomial_7   FP_all      0
# 911     1045           rbf   FP_all      0
# 912     1045            rq   FP_all      0
# 913     1046         akima   FP_all      0
# 914     1046   cubicspline   FP_all      0
# 915     1046       cut_glc   FP_all      0
# 916     1046        linear   FP_all      0
# 917     1046        matern   FP_all      0
# 918     1046         pchip   FP_all      0
# 919     1046  polynomial_3   FP_all      0
# 920     1046  polynomial_5   FP_all      0
# 921     1046  polynomial_7   FP_all      0
# 922     1046           rbf   FP_all      0
# 923     1046            rq   FP_all      0
# 924     1047         akima   FP_all      0
# 925     1047   cubicspline   FP_all      0
# 926     1047       cut_glc   FP_all      0
# 927     1047        linear   FP_all      0
# 928     1047        matern   FP_all      0
# 929     1047         pchip   FP_all      0
# 930     1047  polynomial_3   FP_all      0
# 931     1047  polynomial_5   FP_all      0
# 932     1047  polynomial_7   FP_all      0
# 933     1047           rbf   FP_all      0
# 934     1047            rq   FP_all      0
# 935     1048         akima   FP_all      0
# 936     1048   cubicspline   FP_all      0
# 937     1048       cut_glc   FP_all      0
# 938     1048        linear   FP_all      0
# 939     1048        matern   FP_all      0
# 940     1048         pchip   FP_all      0
# 941     1048  polynomial_3   FP_all      0
# 942     1048  polynomial_5   FP_all      0
# 943     1048  polynomial_7   FP_all      0
# 944     1048           rbf   FP_all      0
# 945     1048            rq   FP_all      0
# 946     1049         akima   FP_all      0
# 947     1049   cubicspline   FP_all      0
# 948     1049       cut_glc   FP_all      0
# 949     1049        linear   FP_all      0
# 950     1049        matern   FP_all      0
# 951     1049         pchip   FP_all      0
# 952     1049  polynomial_3   FP_all      0
# 953     1049  polynomial_5   FP_all      0
# 954     1049  polynomial_7   FP_all      0
# 955     1049           rbf   FP_all      0
# 956     1049            rq   FP_all      0
# 957     1051         akima   FP_all      0
# 958     1051   cubicspline   FP_all      1
# 959     1051       cut_glc   FP_all      0
# 960     1051        linear   FP_all      0
# 961     1051        matern   FP_all      1
# 962     1051         pchip   FP_all      0
# 963     1051  polynomial_3   FP_all      1
# 964     1051  polynomial_5   FP_all      1
# 965     1051  polynomial_7   FP_all      1
# 966     1051           rbf   FP_all      1
# 967     1051            rq   FP_all      0
# 968     2001         akima   FP_all      0
# 969     2001   cubicspline   FP_all      0
# 970     2001       cut_glc   FP_all      0
# 971     2001        linear   FP_all      0
# 972     2001        matern   FP_all      0
# 973     2001         pchip   FP_all      0
# 974     2001  polynomial_3   FP_all      0
# 975     2001  polynomial_5   FP_all      0
# 976     2001  polynomial_7   FP_all      0
# 977     2001           rbf   FP_all      0
# 978     2001            rq   FP_all      0
# 979     2003         akima   FP_all      1
# 980     2003   cubicspline   FP_all      1
# 981     2003       cut_glc   FP_all      0
# 982     2003        linear   FP_all      0
# 983     2003        matern   FP_all      1
# 984     2003         pchip   FP_all      1
# 985     2003  polynomial_3   FP_all      1
# 986     2003  polynomial_5   FP_all      1
# 987     2003  polynomial_7   FP_all      1
# 988     2003           rbf   FP_all      1
# 989     2003            rq   FP_all      1
# 990     2004         akima   FP_all      0
# 991     2004   cubicspline   FP_all      0
# 992     2004       cut_glc   FP_all      0
# 993     2004        linear   FP_all      0
# 994     2004        matern   FP_all      0
# 995     2004         pchip   FP_all      0
# 996     2004  polynomial_3   FP_all      0
# 997     2004  polynomial_5   FP_all      0
# 998     2004  polynomial_7   FP_all      0
# 999     2004           rbf   FP_all      0
# 1000    2004            rq   FP_all      0
# 1001    2008         akima   FP_all      1
# 1002    2008   cubicspline   FP_all      1
# 1003    2008       cut_glc   FP_all      0
# 1004    2008        linear   FP_all      1
# 1005    2008        matern   FP_all      1
# 1006    2008         pchip   FP_all      1
# 1007    2008  polynomial_3   FP_all      1
# 1008    2008  polynomial_5   FP_all      1
# 1009    2008  polynomial_7   FP_all      1
# 1010    2008           rbf   FP_all      1
# 1011    2008            rq   FP_all      1
# 1012    2009         akima   FP_all      0
# 1013    2009   cubicspline   FP_all      0
# 1014    2009       cut_glc   FP_all      0
# 1015    2009        linear   FP_all      0
# 1016    2009        matern   FP_all      0
# 1017    2009         pchip   FP_all      0
# 1018    2009  polynomial_3   FP_all      0
# 1019    2009  polynomial_5   FP_all      0
# 1020    2009  polynomial_7   FP_all      0
# 1021    2009           rbf   FP_all      0
# 1022    2009            rq   FP_all      0
# 1023    2012         akima   FP_all      2
# 1024    2012   cubicspline   FP_all      2
# 1025    2012       cut_glc   FP_all      0
# 1026    2012        linear   FP_all      1
# 1027    2012        matern   FP_all      2
# 1028    2012         pchip   FP_all      2
# 1029    2012  polynomial_3   FP_all      2
# 1030    2012  polynomial_5   FP_all      2
# 1031    2012  polynomial_7   FP_all      2
# 1032    2012           rbf   FP_all      2
# 1033    2012            rq   FP_all      2
# 1034    2013         akima   FP_all      0
# 1035    2013   cubicspline   FP_all      0
# 1036    2013       cut_glc   FP_all      0
# 1037    2013        linear   FP_all      0
# 1038    2013        matern   FP_all      0
# 1039    2013         pchip   FP_all      0
# 1040    2013  polynomial_3   FP_all      0
# 1041    2013  polynomial_5   FP_all      0
# 1042    2013  polynomial_7   FP_all      0
# 1043    2013           rbf   FP_all      0
# 1044    2013            rq   FP_all      0
# 1045    2016         akima   FP_all      0
# 1046    2016   cubicspline   FP_all      0
# 1047    2016       cut_glc   FP_all      0
# 1048    2016        linear   FP_all      0
# 1049    2016        matern   FP_all      0
# 1050    2016         pchip   FP_all      0
# 1051    2016  polynomial_3   FP_all      0
# 1052    2016  polynomial_5   FP_all      0
# 1053    2016  polynomial_7   FP_all      0
# 1054    2016           rbf   FP_all      0
# 1055    2016            rq   FP_all      0
# 1056    2017         akima   FP_all      0
# 1057    2017   cubicspline   FP_all      0
# 1058    2017       cut_glc   FP_all      0
# 1059    2017        linear   FP_all      0
# 1060    2017        matern   FP_all      0
# 1061    2017         pchip   FP_all      0
# 1062    2017  polynomial_3   FP_all      0
# 1063    2017  polynomial_5   FP_all      0
# 1064    2017  polynomial_7   FP_all      0
# 1065    2017           rbf   FP_all      0
# 1066    2017            rq   FP_all      0
# 1067    2020         akima   FP_all      0
# 1068    2020   cubicspline   FP_all      0
# 1069    2020       cut_glc   FP_all      0
# 1070    2020        linear   FP_all      0
# 1071    2020        matern   FP_all      0
# 1072    2020         pchip   FP_all      0
# 1073    2020  polynomial_3   FP_all      0
# 1074    2020  polynomial_5   FP_all      0
# 1075    2020  polynomial_7   FP_all      0
# 1076    2020           rbf   FP_all      0
# 1077    2020            rq   FP_all      0
# 1078    2023         akima   FP_all      0
# 1079    2023   cubicspline   FP_all      0
# 1080    2023       cut_glc   FP_all      0
# 1081    2023        linear   FP_all      0
# 1082    2023        matern   FP_all      0
# 1083    2023         pchip   FP_all      0
# 1084    2023  polynomial_3   FP_all      0
# 1085    2023  polynomial_5   FP_all      0
# 1086    2023  polynomial_7   FP_all      0
# 1087    2023           rbf   FP_all      0
# 1088    2023            rq   FP_all      0
# 1089    2024         akima   FP_all      0
# 1090    2024   cubicspline   FP_all      0
# 1091    2024       cut_glc   FP_all      0
# 1092    2024        linear   FP_all      0
# 1093    2024        matern   FP_all      0
# 1094    2024         pchip   FP_all      0
# 1095    2024  polynomial_3   FP_all      0
# 1096    2024  polynomial_5   FP_all      0
# 1097    2024  polynomial_7   FP_all      0
# 1098    2024           rbf   FP_all      0
# 1099    2024            rq   FP_all      0
# 1100    2026         akima   FP_all      0
# 1101    2026   cubicspline   FP_all      0
# 1102    2026       cut_glc   FP_all      0
# 1103    2026        linear   FP_all      0
# 1104    2026        matern   FP_all      0
# 1105    2026         pchip   FP_all      0
# 1106    2026  polynomial_3   FP_all      0
# 1107    2026  polynomial_5   FP_all      0
# 1108    2026  polynomial_7   FP_all      0
# 1109    2026           rbf   FP_all      0
# 1110    2026            rq   FP_all      0
# 1111    2027         akima   FP_all      0
# 1112    2027   cubicspline   FP_all      0
# 1113    2027       cut_glc   FP_all      0
# 1114    2027        linear   FP_all      0
# ...
# 5370    1045       cut_glc    FNlv2      1
# 5371    1045        linear    FNlv2      1
# 5372    1045        matern    FNlv2      0
# 5373    1045         pchip    FNlv2      0
# 5374    1045  polynomial_3    FNlv2      0
# 5375    1045  polynomial_5    FNlv2      0
# 5376    1045  polynomial_7    FNlv2      0
# 5377    1045           rbf    FNlv2      0
# 5378    1045            rq    FNlv2      1
# 5379    1046         akima    FNlv2      0
# 5380    1046   cubicspline    FNlv2      0
# 5381    1046       cut_glc    FNlv2      0
# 5382    1046        linear    FNlv2      0
# 5383    1046        matern    FNlv2      1
# 5384    1046         pchip    FNlv2      0
# 5385    1046  polynomial_3    FNlv2      0
# 5386    1046  polynomial_5    FNlv2      0
# 5387    1046  polynomial_7    FNlv2      0
# 5388    1046           rbf    FNlv2      0
# 5389    1046            rq    FNlv2      0
# 5390    1047         akima    FNlv2      0
# 5391    1047   cubicspline    FNlv2      0
# 5392    1047       cut_glc    FNlv2      0
# 5393    1047        linear    FNlv2      0
# 5394    1047        matern    FNlv2      0
# 5395    1047         pchip    FNlv2      0
# 5396    1047  polynomial_3    FNlv2      0
# 5397    1047  polynomial_5    FNlv2      0
# 5398    1047  polynomial_7    FNlv2      0
# 5399    1047           rbf    FNlv2      0
# 5400    1047            rq    FNlv2      0
# 5401    1048         akima    FNlv2      0
# 5402    1048   cubicspline    FNlv2      0
# 5403    1048       cut_glc    FNlv2      0
# 5404    1048        linear    FNlv2      0
# 5405    1048        matern    FNlv2      0
# 5406    1048         pchip    FNlv2      0
# 5407    1048  polynomial_3    FNlv2      0
# 5408    1048  polynomial_5    FNlv2      0
# 5409    1048  polynomial_7    FNlv2      0
# 5410    1048           rbf    FNlv2      0
# 5411    1048            rq    FNlv2      0
# 5412    1049         akima    FNlv2      0
# 5413    1049   cubicspline    FNlv2      0
# 5414    1049       cut_glc    FNlv2      0
# 5415    1049        linear    FNlv2      0
# 5416    1049        matern    FNlv2      0
# 5417    1049         pchip    FNlv2      0
# 5418    1049  polynomial_3    FNlv2      0
# 5419    1049  polynomial_5    FNlv2      0
# 5420    1049  polynomial_7    FNlv2      0
# 5421    1049           rbf    FNlv2      0
# 5422    1049            rq    FNlv2      0
# 5423    1051         akima    FNlv2      0
# 5424    1051   cubicspline    FNlv2      0
# 5425    1051       cut_glc    FNlv2      0
# 5426    1051        linear    FNlv2      0
# 5427    1051        matern    FNlv2      0
# 5428    1051         pchip    FNlv2      0
# 5429    1051  polynomial_3    FNlv2      0
# 5430    1051  polynomial_5    FNlv2      0
# 5431    1051  polynomial_7    FNlv2      0
# 5432    1051           rbf    FNlv2      0
# 5433    1051            rq    FNlv2      0
# 5434    2001         akima    FNlv2      0
# 5435    2001   cubicspline    FNlv2      0
# 5436    2001       cut_glc    FNlv2      0
# 5437    2001        linear    FNlv2      0
# 5438    2001        matern    FNlv2      0
# 5439    2001         pchip    FNlv2      0
# 5440    2001  polynomial_3    FNlv2      0
# 5441    2001  polynomial_5    FNlv2      0
# 5442    2001  polynomial_7    FNlv2      0
# 5443    2001           rbf    FNlv2      0
# 5444    2001            rq    FNlv2      0
# 5445    2003         akima    FNlv2      0
# 5446    2003   cubicspline    FNlv2      0
# 5447    2003       cut_glc    FNlv2      0
# 5448    2003        linear    FNlv2      0
# 5449    2003        matern    FNlv2      0
# 5450    2003         pchip    FNlv2      0
# 5451    2003  polynomial_3    FNlv2      0
# 5452    2003  polynomial_5    FNlv2      0
# 5453    2003  polynomial_7    FNlv2      0
# 5454    2003           rbf    FNlv2      0
# 5455    2003            rq    FNlv2      0
# 5456    2004         akima    FNlv2      0
# 5457    2004   cubicspline    FNlv2      0
# 5458    2004       cut_glc    FNlv2      0
# 5459    2004        linear    FNlv2      0
# 5460    2004        matern    FNlv2      0
# 5461    2004         pchip    FNlv2      0
# 5462    2004  polynomial_3    FNlv2      0
# 5463    2004  polynomial_5    FNlv2      0
# 5464    2004  polynomial_7    FNlv2      0
# 5465    2004           rbf    FNlv2      0
# 5466    2004            rq    FNlv2      0
# 5467    2008         akima    FNlv2      0
# 5468    2008   cubicspline    FNlv2      0
# 5469    2008       cut_glc    FNlv2      0
# 5470    2008        linear    FNlv2      0
# 5471    2008        matern    FNlv2      0
# 5472    2008         pchip    FNlv2      0
# 5473    2008  polynomial_3    FNlv2      0
# 5474    2008  polynomial_5    FNlv2      0
# 5475    2008  polynomial_7    FNlv2      0
# 5476    2008           rbf    FNlv2      0
# 5477    2008            rq    FNlv2      0
# 5478    2009         akima    FNlv2      0
# 5479    2009   cubicspline    FNlv2      0
# 5480    2009       cut_glc    FNlv2      1
# 5481    2009        linear    FNlv2      1
# 5482    2009        matern    FNlv2      0
# 5483    2009         pchip    FNlv2      0
# 5484    2009  polynomial_3    FNlv2      0
# 5485    2009  polynomial_5    FNlv2      0
# 5486    2009  polynomial_7    FNlv2      0
# 5487    2009           rbf    FNlv2      0
# 5488    2009            rq    FNlv2      0
# 5489    2012         akima    FNlv2      1
# 5490    2012   cubicspline    FNlv2      1
# 5491    2012       cut_glc    FNlv2      1
# 5492    2012        linear    FNlv2      1
# 5493    2012        matern    FNlv2      1
# 5494    2012         pchip    FNlv2      1
# 5495    2012  polynomial_3    FNlv2      1
# 5496    2012  polynomial_5    FNlv2      1
# 5497    2012  polynomial_7    FNlv2      1
# 5498    2012           rbf    FNlv2      1
# 5499    2012            rq    FNlv2      1
# 5500    2013         akima    FNlv2      0
# 5501    2013   cubicspline    FNlv2      0
# 5502    2013       cut_glc    FNlv2      0
# 5503    2013        linear    FNlv2      0
# 5504    2013        matern    FNlv2      0
# 5505    2013         pchip    FNlv2      0
# 5506    2013  polynomial_3    FNlv2      0
# 5507    2013  polynomial_5    FNlv2      0
# 5508    2013  polynomial_7    FNlv2      0
# 5509    2013           rbf    FNlv2      0
# 5510    2013            rq    FNlv2      0
# 5511    2016         akima    FNlv2      0
# 5512    2016   cubicspline    FNlv2      0
# 5513    2016       cut_glc    FNlv2      0
# 5514    2016        linear    FNlv2      0
# 5515    2016        matern    FNlv2      0
# 5516    2016         pchip    FNlv2      0
# 5517    2016  polynomial_3    FNlv2      0
# 5518    2016  polynomial_5    FNlv2      0
# 5519    2016  polynomial_7    FNlv2      0
# 5520    2016           rbf    FNlv2      0
# 5521    2016            rq    FNlv2      0
# 5522    2017         akima    FNlv2      0
# 5523    2017   cubicspline    FNlv2      0
# 5524    2017       cut_glc    FNlv2      0
# 5525    2017        linear    FNlv2      0
# 5526    2017        matern    FNlv2      0
# 5527    2017         pchip    FNlv2      0
# 5528    2017  polynomial_3    FNlv2      0
# 5529    2017  polynomial_5    FNlv2      0
# 5530    2017  polynomial_7    FNlv2      0
# 5531    2017           rbf    FNlv2      0
# 5532    2017            rq    FNlv2      0
# 5533    2020         akima    FNlv2      0
# 5534    2020   cubicspline    FNlv2      0
# 5535    2020       cut_glc    FNlv2      0
# 5536    2020        linear    FNlv2      0
# 5537    2020        matern    FNlv2      0
# 5538    2020         pchip    FNlv2      0
# 5539    2020  polynomial_3    FNlv2      0
# 5540    2020  polynomial_5    FNlv2      0
# 5541    2020  polynomial_7    FNlv2      0
# 5542    2020           rbf    FNlv2      0
# 5543    2020            rq    FNlv2      0
# 5544    2023         akima    FNlv2      0
# 5545    2023   cubicspline    FNlv2      0
# 5546    2023       cut_glc    FNlv2      0
# 5547    2023        linear    FNlv2      0
# 5548    2023        matern    FNlv2      0
# 5549    2023         pchip    FNlv2      0
# 5550    2023  polynomial_3    FNlv2      0
# 5551    2023  polynomial_5    FNlv2      0
# 5552    2023  polynomial_7    FNlv2      0
# 5553    2023           rbf    FNlv2      0
# 5554    2023            rq    FNlv2      0
# 5555    2024         akima    FNlv2      0
# 5556    2024   cubicspline    FNlv2      0
# 5557    2024       cut_glc    FNlv2      1
# 5558    2024        linear    FNlv2      1
# 5559    2024        matern    FNlv2      0
# 5560    2024         pchip    FNlv2      0
# 5561    2024  polynomial_3    FNlv2      0
# 5562    2024  polynomial_5    FNlv2      0
# 5563    2024  polynomial_7    FNlv2      0
# 5564    2024           rbf    FNlv2      0
# 5565    2024            rq    FNlv2      1
# 5566    2026         akima    FNlv2      0
# 5567    2026   cubicspline    FNlv2      0
# 5568    2026       cut_glc    FNlv2      1
# 5569    2026        linear    FNlv2      1
# 5570    2026        matern    FNlv2      0
# 5571    2026         pchip    FNlv2      1
# 5572    2026  polynomial_3    FNlv2      0
# 5573    2026  polynomial_5    FNlv2      0
# 5574    2026  polynomial_7    FNlv2      0
# 5575    2026           rbf    FNlv2      0
# 5576    2026            rq    FNlv2      0
# 5577    2027         akima    FNlv2      0
# 5578    2027   cubicspline    FNlv2      0
# 5579    2027       cut_glc    FNlv2      0
# 5580    2027        linear    FNlv2      0
# 5581    2027        matern    FNlv2      0
# 5582    2027         pchip    FNlv2      0
# 5583    2027  polynomial_3    FNlv2      0
# 5584    2027  polynomial_5    FNlv2      0
# 5585    2027  polynomial_7    FNlv2      0
# 5586    2027           rbf    FNlv2      0
# 5587    2027            rq    FNlv2      0
# 5588    2028         akima    FNlv2      0
# 5589    2028   cubicspline    FNlv2      0
# 5590    2028       cut_glc    FNlv2      1
# 5591    2028        linear    FNlv2      0
# 5592    2028        matern    FNlv2      0
# 5593    2028         pchip    FNlv2      0
# 5594    2028  polynomial_3    FNlv2      0
# 5595    2028  polynomial_5    FNlv2      0
# 5596    2028  polynomial_7    FNlv2      0
# 5597    2028           rbf    FNlv2      0
# 5598    2028            rq    FNlv2      0
# 5599    2029         akima    FNlv2      0
# 5600    2029   cubicspline    FNlv2      0
# 5601    2029       cut_glc    FNlv2      0
# 5602    2029        linear    FNlv2      0
# 5603    2029        matern    FNlv2      0
# 5604    2029         pchip    FNlv2      0
# 5605    2029  polynomial_3    FNlv2      0
# 5606    2029  polynomial_5    FNlv2      0
# 5607    2029  polynomial_7    FNlv2      0
# 5608    2029           rbf    FNlv2      0
# 5609    2029            rq    FNlv2      0
# 5610    2030         akima    FNlv2      1
# 5611    2030   cubicspline    FNlv2      1
# 5612    2030       cut_glc    FNlv2      1
# 5613    2030        linear    FNlv2      1
# 5614    2030        matern    FNlv2      0
# 5615    2030         pchip    FNlv2      0
# 5616    2030  polynomial_3    FNlv2      1
# 5617    2030  polynomial_5    FNlv2      0
# 5618    2030  polynomial_7    FNlv2      0
# 5619    2030           rbf    FNlv2      0
# 5620    2030            rq    FNlv2      1
# 5621    2031         akima    FNlv2      0
# 5622    2031   cubicspline    FNlv2      0
# 5623    2031       cut_glc    FNlv2      0
# 5624    2031        linear    FNlv2      0
# 5625    2031        matern    FNlv2      0
# 5626    2031         pchip    FNlv2      0
# 5627    2031  polynomial_3    FNlv2      0
# 5628    2031  polynomial_5    FNlv2      0
# 5629    2031  polynomial_7    FNlv2      0
# 5630    2031           rbf    FNlv2      0
# 5631    2031            rq    FNlv2      0
# 5632    2032         akima    FNlv2      0
# 5633    2032   cubicspline    FNlv2      0
# 5634    2032       cut_glc    FNlv2      0
# 5635    2032        linear    FNlv2      0
# 5636    2032        matern    FNlv2      0
# 5637    2032         pchip    FNlv2      0
# 5638    2032  polynomial_3    FNlv2      0
# 5639    2032  polynomial_5    FNlv2      0
# 5640    2032  polynomial_7    FNlv2      0
# 5641    2032           rbf    FNlv2      0
# 5642    2032            rq    FNlv2      0
# 5643    2035         akima    FNlv2      0
# 5644    2035   cubicspline    FNlv2      0
# 5645    2035       cut_glc    FNlv2      0
# 5646    2035        linear    FNlv2      0
# 5647    2035        matern    FNlv2      0
# 5648    2035         pchip    FNlv2      0
# 5649    2035  polynomial_3    FNlv2      0
# 5650    2035  polynomial_5    FNlv2      0
# 5651    2035  polynomial_7    FNlv2      0
# 5652    2035           rbf    FNlv2      0
# 5653    2035            rq    FNlv2      0
# 5654    2036         akima    FNlv2      0
# 5655    2036   cubicspline    FNlv2      0
# 5656    2036       cut_glc    FNlv2      0
# 5657    2036        linear    FNlv2      0
# 5658    2036        matern    FNlv2      0
# 5659    2036         pchip    FNlv2      0
# 5660    2036  polynomial_3    FNlv2      0
# 5661    2036  polynomial_5    FNlv2      0
# 5662    2036  polynomial_7    FNlv2      0
# 5663    2036           rbf    FNlv2      0
# 5664    2036            rq    FNlv2      0
# 5665    2038         akima    FNlv2      0
# 5666    2038   cubicspline    FNlv2      0
# 5667    2038       cut_glc    FNlv2      1
# 5668    2038        linear    FNlv2      0
# 5669    2038        matern    FNlv2      0
# 5670    2038         pchip    FNlv2      0
# 5671    2038  polynomial_3    FNlv2      0
# 5672    2038  polynomial_5    FNlv2      0
# 5673    2038  polynomial_7    FNlv2      0
# 5674    2038           rbf    FNlv2      0
# 5675    2038            rq    FNlv2      0
# 5676    2039         akima    FNlv2      0
# 5677    2039   cubicspline    FNlv2      0
# 5678    2039       cut_glc    FNlv2      0
# 5679    2039        linear    FNlv2      0
# 5680    2039        matern    FNlv2      0
# 5681    2039         pchip    FNlv2      0
# 5682    2039  polynomial_3    FNlv2      0
# 5683    2039  polynomial_5    FNlv2      0
# 5684    2039  polynomial_7    FNlv2      0
# 5685    2039           rbf    FNlv2      0
# 5686    2039            rq    FNlv2      0
# 5687    2040         akima    FNlv2      0
# 5688    2040   cubicspline    FNlv2      0
# 5689    2040       cut_glc    FNlv2      1
# 5690    2040        linear    FNlv2      0
# 5691    2040        matern    FNlv2      0
# 5692    2040         pchip    FNlv2      0
# 5693    2040  polynomial_3    FNlv2      0
# 5694    2040  polynomial_5    FNlv2      0
# 5695    2040  polynomial_7    FNlv2      0
# 5696    2040           rbf    FNlv2      0
# 5697    2040            rq    FNlv2      0
# 5698    2041         akima    FNlv2      0
# 5699    2041   cubicspline    FNlv2      0
# 5700    2041       cut_glc    FNlv2      0
# 5701    2041        linear    FNlv2      0
# 5702    2041        matern    FNlv2      0
# 5703    2041         pchip    FNlv2      0
# 5704    2041  polynomial_3    FNlv2      0
# 5705    2041  polynomial_5    FNlv2      0
# 5706    2041  polynomial_7    FNlv2      0
# 5707    2041           rbf    FNlv2      0
# 5708    2041            rq    FNlv2      0
# 5709    2042         akima    FNlv2      0
# 5710    2042   cubicspline    FNlv2      0
# 5711    2042       cut_glc    FNlv2      0
# 5712    2042        linear    FNlv2      0
# 5713    2042        matern    FNlv2      0
# 5714    2042         pchip    FNlv2      0
# 5715    2042  polynomial_3    FNlv2      0
# 5716    2042  polynomial_5    FNlv2      0
# 5717    2042  polynomial_7    FNlv2      0
# 5718    2042           rbf    FNlv2      0
# 5719    2042            rq    FNlv2      0
# 5720    2043         akima    FNlv2      0
# 5721    2043   cubicspline    FNlv2      0
# 5722    2043       cut_glc    FNlv2      0
# 5723    2043        linear    FNlv2      0
# 5724    2043        matern    FNlv2      0
# 5725    2043         pchip    FNlv2      0
# 5726    2043  polynomial_3    FNlv2      0
# 5727    2043  polynomial_5    FNlv2      0
# 5728    2043  polynomial_7    FNlv2      0
# 5729    2043           rbf    FNlv2      0
# 5730    2043            rq    FNlv2      0
# 5731    2045         akima    FNlv2      0
# 5732    2045   cubicspline    FNlv2      0
# 5733    2045       cut_glc    FNlv2      1
# 5734    2045        linear    FNlv2      1
# 5735    2045        matern    FNlv2      0
# 5736    2045         pchip    FNlv2      1
# 5737    2045  polynomial_3    FNlv2      0
# 5738    2045  polynomial_5    FNlv2      0
# 5739    2045  polynomial_7    FNlv2      0
# 5740    2045           rbf    FNlv2      0
# 5741    2045            rq    FNlv2      1

# %%
pd.DataFrame(melted.groupby(['col', 'variable']).apply(lambda x: x[x.value!=0].shape[0])).reset_index().pivot(index='col', columns='variable')
# Out:
#                   0
# variable     FN_all FNlv1 FNlv2 FP_all FPlv1 FPlv2 TP_all TPlv1 TPlv2
# col
# akima            11    16     8      9    16     7     57    54    44
# cubicspline       9    15     7     11    16    10     57    54    44
# cut_glc          25    22    21      1    19     0     57    54    42
# linear           14    16    14      4    17     2     57    54    43
# matern            9    14     7     11    15    10     57    54    44
# pchip            10    17    10      7    15     8     57    54    43
# polynomial_3      9    15     7     11    16    10     57    54    44
# polynomial_5      8    15     6     11    15    11     57    54    44
# polynomial_7     10    16     6     11    15    11     57    54    44
# rbf              10    15     6     11    15     9     57    54    44
# rq               13    17    12      8    18     6     57    54    43
